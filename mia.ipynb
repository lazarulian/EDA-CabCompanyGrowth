# %%
## Initial Import
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import nbformat
from plotly.graph_objs import Bar, Scatter, Figure, Layout
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True) 
from scipy import stats
from plotly.graph_objs import *
import datetime
import plotly.graph_objects as go
import seaborn as sns
from datetime import datetime, timedelta
import plotly.express as px
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Initial Data Cleansing Procedure

# %%
df = pd.read_csv('data.csv')

# %%
df.head(6)
# Out:
#   Participant ID       Condition  Speed Subtitles  Age  Prediction  \
# 0        5004125  2.0x-subtitles      2       yes   22        20.0
# 1        5262911            1.0x      1        no   20        10.0
# 2        5304746  2.0x-subtitles      2       yes   21        18.0
# 3        5312505  1.0x-subtitles      1       yes   20        20.0
# 4        5317838            1.0x      1        no   20        10.0
# 5        5320826  3.0x-subtitles      3       yes   21         5.0
#
#    Prediction Proportion  Accuracy  Accuracy Proportion
# 0                   0.80        23                 0.92
# 1                   0.40        15                 0.60
# 2                   0.72        18                 0.72
# 3                   0.80        19                 0.76
# 4                   0.40        19                 0.76
# 5                   0.20         7                 0.28

# %%
df.tail(6)
# Out:
#       Participant ID       Condition  Speed Subtitles  Age  Prediction  \
# 339        905845981            3.0x      3        no   19         5.0
# 340       1055411993  2.0x-subtitles      2       yes   23        20.0
# 341       3058383219  1.0x-subtitles      1       yes   41         7.0
# 342       8056749567  3.0x-subtitles      3       yes   18         3.0
# 343        4-5787592  3.0x-subtitles      3       yes   18        10.0
# 344  j26J3p7CZgkMCie            2.0x      2        no   21        20.0
#
#      Prediction Proportion  Accuracy  Accuracy Proportion
# 339                   0.20         7                 0.28
# 340                   0.80        20                 0.80
# 341                   0.28        12                 0.48
# 342                   0.12         7                 0.28
# 343                   0.40        13                 0.52
# 344                   0.80         9                 0.36

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 345 entries, 0 to 344
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Participant ID         345 non-null    object
#  1   Condition              345 non-null    object
#  2   Speed                  345 non-null    int64
#  3   Subtitles              345 non-null    object
#  4   Age                    345 non-null    int64
#  5   Prediction             344 non-null    float64
#  6   Prediction Proportion  345 non-null    float64
#  7   Accuracy               345 non-null    int64
#  8   Accuracy Proportion    345 non-null    float64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 24.4+ KB

# %%
def removeSpaces(frame):
    frame.columns = frame.columns.str.replace(' ', '_')

# %%
removeSpaces(df)

# %%
df.head()
# Out:
#   Participant_ID       Condition  Speed Subtitles  Age  Prediction  \
# 0        5004125  2.0x-subtitles      2       yes   22        20.0
# 1        5262911            1.0x      1        no   20        10.0
# 2        5304746  2.0x-subtitles      2       yes   21        18.0
# 3        5312505  1.0x-subtitles      1       yes   20        20.0
# 4        5317838            1.0x      1        no   20        10.0
#
#    Prediction_Proportion  Accuracy  Accuracy_Proportion
# 0                   0.80        23                 0.92
# 1                   0.40        15                 0.60
# 2                   0.72        18                 0.72
# 3                   0.80        19                 0.76
# 4                   0.40        19                 0.76

# %% [markdown]
# ## Data Visualization

# %%
graph_0 = df.groupby(["Subtitles"]).Prediction_Proportion
# px.scatter(x= df.Speed, y= df.Prediction_Proportion, title = "Prediction Proportion vs. Playback Speed")

# plt.scatter(x= df.Speed, y= df.Prediction_Proportion, c="blue", alpha=0.5)
# fig, ax = plt.subplots()
# ax.plot(df.Speed, df.Prediction_Proportion)
# plt.title('Prediction Proportion vs. Playback Speed')
# plt.xlabel("Playback Speed")
# plt.ylabel("Prediction Proportion")
# plt.show()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))
ax1.scatter(df.Speed, df.Prediction_Proportion)
ax2.scatter(df.Speed, df.Accuracy_Proportion)
ax1.set_xlabel("Playback Speed")
ax2.set_xlabel("Playback Speed")
ax1.set_ylabel("Prediction Proportion")
ax2.set_ylabel("Accuracy Proportion")
ax1.set_title("Prediction Proportion vs. Playback Speed")
ax2.set_title("Accuracy Proportion vs. Playback Speed")
# Out:
# Text(0.5, 1.0, 'Accuracy Proportion vs. Playback Speed')
